# %%
import numpy as np

# %%
np.identity(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
A = [1,2,3,4,5,6]

# %%
B = [13,21,24]

# %%
A.extend(B)

# %%
import pandas as pd

# %%
df1 = pd.read_csv(r"https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv")

# %%
df1.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
df1.describe
# Out:
# <bound method NDFrame.describe of                       record_id  utility_id_ferc1  report_year  \
# 0         f1_fuel_1994_12_1_0_7                 1         1994
# 1        f1_fuel_1994_12_1_0_10                 1         1994
# 2         f1_fuel_1994_12_2_0_1                 2         1994
# 3         f1_fuel_1994_12_2_0_7                 2         1994
# 4        f1_fuel_1994_12_2_0_10                 2         1994
# 5        f1_fuel_1994_12_2_0_13                 2         1994
# 6         f1_fuel_1994_12_2_1_1                 2         1994
# 7        f1_fuel_1994_12_2_1_10                 2         1994
# 8        f1_fuel_1994_12_2_2_10                 2         1994
# 9         f1_fuel_1994_12_4_0_1                 4         1994
# 10        f1_fuel_1994_12_4_0_2                 4         1994
# 11        f1_fuel_1994_12_4_0_4                 4         1994
# 12        f1_fuel_1994_12_4_0_5                 4         1994
# ...

# %%
df1.groupby("fuel_type_code_pudl")["fuel_cost_per_unit_burned"].mean()
# Out:
# fuel_type_code_pudl
# coal         67.421830
# gas          13.659397
# nuclear    4955.157002
# oil         168.877086
# other        18.253856
# waste        19.518122
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
round(df1.std(axis = 0),2)
# Out:
# utility_id_ferc1                     74.18
# report_year                           7.03
# fuel_qty_burned                 9118003.53
# fuel_mmbtu_per_unit                  10.60
# fuel_cost_per_unit_burned          2854.49
# fuel_cost_per_unit_delivered      68775.93
# fuel_cost_per_mmbtu                2091.54
# dtype: float64

# %%
round(df1.quantile(.75, axis=0),2)
# Out:
# utility_id_ferc1                    176.00
# report_year                        2012.00
# fuel_qty_burned                 1424034.00
# fuel_mmbtu_per_unit                  17.01
# fuel_cost_per_unit_burned            47.11
# fuel_cost_per_unit_delivered         42.14
# fuel_cost_per_mmbtu                   7.74
# Name: 0.75, dtype: float64

# %%
round(df1.kurtosis(axis=0),2)
# Out:
# utility_id_ferc1                    1.09
# report_year                        -1.15
# fuel_qty_burned                   651.37
# fuel_mmbtu_per_unit                55.60
# fuel_cost_per_unit_burned         485.26
# fuel_cost_per_unit_delivered    11765.05
# fuel_cost_per_mmbtu             29489.13
# dtype: float64

# %%
round(df1.skew(axis=0),2)
# Out:
# utility_id_ferc1                  0.605070
# report_year                       0.006953
# fuel_qty_burned                  15.851495
# fuel_mmbtu_per_unit               4.135217
# fuel_cost_per_unit_burned        19.787440
# fuel_cost_per_unit_delivered    105.014227
# fuel_cost_per_mmbtu             171.675535
# dtype: float64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29523 entries, 0 to 29522
# Data columns (total 11 columns):
# record_id                       29523 non-null object
# utility_id_ferc1                29523 non-null int64
# report_year                     29523 non-null int64
# plant_name_ferc1                29523 non-null object
# fuel_type_code_pudl             29523 non-null object
# fuel_unit                       29343 non-null object
# fuel_qty_burned                 29523 non-null float64
# fuel_mmbtu_per_unit             29523 non-null float64
# fuel_cost_per_unit_burned       29523 non-null float64
# fuel_cost_per_unit_delivered    29523 non-null float64
# fuel_cost_per_mmbtu             29523 non-null float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 2.5+ MB

# %%
df1["fuel_unit"].head(5)
# Out:
# 0    ton
# 1    ton
# 2    ton
# 3    ton
# 4    mcf
# Name: fuel_unit, dtype: object

# %%
df1.corr(method ="pearson")
# Out:
#                               utility_id_ferc1  report_year  fuel_qty_burned  \
# utility_id_ferc1                      1.000000     0.093323        -0.057447
# report_year                           0.093323     1.000000         0.012952
# fuel_qty_burned                      -0.057447     0.012952         1.000000
# fuel_mmbtu_per_unit                  -0.066946    -0.110853        -0.080946
# fuel_cost_per_unit_burned            -0.037863     0.013599        -0.018535
# fuel_cost_per_unit_delivered         -0.016414    -0.014043        -0.003551
# fuel_cost_per_mmbtu                   0.006122     0.010261        -0.001896
#
#                               fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# utility_id_ferc1                        -0.066946                  -0.037863
# report_year                             -0.110853                   0.013599
# fuel_qty_burned                         -0.080946                  -0.018535
# ...

# %%
df1.groupby("report_year")["fuel_cost_per_unit_delivered"].mean()
# Out:
# report_year
# 1994       63.636060
# 1995       32.735269
# 1996     9196.705948
# 1997    11140.197239
# 1998      287.154420
# 1999       25.551627
# 2000      985.362877
# 2001       60.050396
# 2002       47.594361
# 2003       55.663493
# 2004      139.524275
# 2005       41.438184
# 2006       38.657484
# 2007       43.325023
# 2008       58.588197
# 2009      652.694163
# 2010       91.862105
# 2011       59.774667
# 2012       60.994502
# 2013      172.307591
# 2014      192.737183
# 2015      326.535511
# 2016      103.901761
# 2017       46.196861
# 2018      499.269966
# Name: fuel_cost_per_unit_delivered, dtype: float64

# %%
df1.groupby(["report_year","fuel_type_code_pudl"])["fuel_cost_per_unit_delivered"].sum()
# Out:
# report_year  fuel_type_code_pudl
# 1994         coal                   5.921537e+04
#              gas                    8.099070e+03
#              nuclear                3.483492e+03
#              oil                    7.622838e+03
#              other                  1.171480e+02
#              waste                  5.261500e+01
# 1995         coal                   1.370415e+04
#              gas                    6.579786e+03
#              nuclear                3.211016e+03
#              oil                    1.584199e+04
#              other                  1.675430e+02
#              waste                 -1.894270e+02
# 1996         coal                   1.208758e+04
#              gas                    1.315040e+03
#              nuclear                9.911224e+06
#              oil                    8.114538e+04
#              other                  1.633100e+02
#              waste                  8.082600e+01
# ...
